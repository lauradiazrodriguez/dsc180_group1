# %%
#!pip install causal-learn pydot graphviz

# %%
from pc_analysis_utils import (plot_comparison_graphs, run_pc_analysis_on_dataset, calculate_and_print_metrics)

# %%
import os
import glob
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Causal-Learn Imports
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils
from causallearn.graph.SHD import SHD 
from causallearn.graph.GraphNode import GraphNode
from causallearn.graph.GeneralGraph import GeneralGraph

# %%
# define top-level directory for datasets
data_dir = 'simulated_data'

# Find all dataset files
all_data_files = sorted(glob.glob(f"{data_dir}/*/*_data.csv"))
# Find all graph.npy files and sort them
all_graph_files = sorted(glob.glob(f"{data_dir}/*/*_graph.npy"))

# check if found same number of data and graph files
if len(all_data_files) == 0:
    print(f"Error: No datasets found in directory '{data_dir}'.")
    print("Please check the 'data_dir' variable.")
elif len(all_data_files) != len(all_graph_files):
    print("Error: # of data files and graph files does not match")
else:
    print(f"Found {len(all_data_files)} datasets. Starting analysis:")
# Out:
# Found 10 datasets. Starting analysis:

# %%
testing = run_pc_analysis_on_dataset(
    all_data_files[0],
    all_graph_files[0],
    alpha=0.05
)
# Out:
# Processing: linear_gaussian_simple_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 4
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 1
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------

# %%
# define top-level directory for datasets
data_dir = 'simulated_data'

# Find all dataset files
all_data_files = sorted(glob.glob(f"{data_dir}/*/*_data.csv"))
# Find all graph.npy files and sort them
all_graph_files = sorted(glob.glob(f"{data_dir}/*/*_graph.npy"))

# check if found same number of data and graph files
if len(all_data_files) == 0:
    print(f"Error: No datasets found in directory '{data_dir}'.")
    print("Please check the 'data_dir' variable.")
elif len(all_data_files) != len(all_graph_files):
    print("Error: # of data files and graph files does not match")
else:
    print(f"Found {len(all_data_files)} datasets. Starting analysis:")
    
# Store results in a dictionary
results_summary = {}

    # Loop through all files and run the analysis
    # using zip() to pair each data file with its corresponding graph file
for data_file, graph_file in zip(all_data_files, all_graph_files):
        
    result = run_pc_analysis_on_dataset(data_file, graph_file, alpha=0.05)
        
        # store SHD score
    dataset_name = os.path.basename(data_file).replace('_data.csv', '')
    results_summary[dataset_name] = result['shd_score']

    #  Print a final summary of all scores 
print("FINAL RESULTS SUMMARY (SHD)")

for name, score in results_summary.items():
    print(f"{name}: {score}")
# Out:
# Found 10 datasets. Starting analysis:
# Processing: linear_gaussian_simple_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 4
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 1
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------
# Processing: linear_gaussian_simple_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 3
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 0
# | FN (Missed Edges): 0
# | Precision: 1.0000
# | Recall:    1.0000
# | F1-Score:  1.0000
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------
# Processing: data_with_error_data.csv
# Running PC alg
#   0%|          | 0/10 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 13
# | Total Learned Edges (TP + FP): 17
# | TP (Correctly Found Edges): 11
# | FP (Spurious Edges): 6
# | FN (Missed Edges): 2
# | Precision: 0.6471
# | Recall:    0.8462
# | F1-Score:  0.7333
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 12
# Learned graph is 12 edge(s) different from the truth.
# -------------------------
# Processing: dense_scale_free_graph_data.csv
# Running PC alg
#   0%|          | 0/15 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 39
# | Total Learned Edges (TP + FP): 19
# | TP (Correctly Found Edges): 16
# | FP (Spurious Edges): 3
# | FN (Missed Edges): 23
# | Precision: 0.8421
# | Recall:    0.4103
# | F1-Score:  0.5517
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 29
# Learned graph is 29 edge(s) different from the truth.
# -------------------------
# Processing: heterogeneous_multi_domain_data.csv
# Running PC alg
#   0%|          | 0/10 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 9
# | Total Learned Edges (TP + FP): 12
# | TP (Correctly Found Edges): 9
# | FP (Spurious Edges): 3
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 3
# Learned graph is 3 edge(s) different from the truth.
# -------------------------
# Processing: linear_gaussian_simple_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 3
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 0
# | FN (Missed Edges): 0
# | Precision: 1.0000
# | Recall:    1.0000
# | F1-Score:  1.0000
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------
# Processing: linear_uniform_noise_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 4
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 1
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------
# Processing: mixed_data_discrete_data.csv
# Running PC alg
#   0%|          | 0/10 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 13
# | Total Learned Edges (TP + FP): 8
# | TP (Correctly Found Edges): 8
# | FP (Spurious Edges): 0
# | FN (Missed Edges): 5
# | Precision: 1.0000
# | Recall:    0.6154
# | F1-Score:  0.7619
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 6
# Learned graph is 6 edge(s) different from the truth.
# -------------------------
# Processing: nonlinear_mlp_data.csv
# Running PC alg
#   0%|          | 0/10 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 9
# | Total Learned Edges (TP + FP): 12
# | TP (Correctly Found Edges): 9
# | FP (Spurious Edges): 3
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 7
# Learned graph is 7 edge(s) different from the truth.
# -------------------------
# Processing: sparse_linear_graph_data.csv
# Running PC alg
#   0%|          | 0/15 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 5
# | Total Learned Edges (TP + FP): 7
# | TP (Correctly Found Edges): 5
# | FP (Spurious Edges): 2
# | FN (Missed Edges): 0
# | Precision: 0.7143
# | Recall:    1.0000
# | F1-Score:  0.8333
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 7
# Learned graph is 7 edge(s) different from the truth.
# -------------------------
# FINAL RESULTS SUMMARY (SHD)
# linear_gaussian_simple: 1
# data_with_error: 12
# dense_scale_free_graph: 29
# heterogeneous_multi_domain: 3
# linear_uniform_noise: 1
# mixed_data_discrete: 6
# nonlinear_mlp: 7
# sparse_linear_graph: 7

# %%
testing = run_pc_analysis_on_dataset(
    all_data_files[0],
    all_graph_files[0],
    alpha=0.05
)
# Out:
# Processing: linear_gaussian_simple_data.csv
# Running PC alg
#   0%|          | 0/5 [00:00<?, ?it/s]
# PC alg finished.
# |--- Structural Metrics (Edges Only) ---
# | Total True Edges (TP + FN): 3
# | Total Learned Edges (TP + FP): 4
# | TP (Correctly Found Edges): 3
# | FP (Spurious Edges): 1
# | FN (Missed Edges): 0
# | Precision: 0.7500
# | Recall:    1.0000
# | F1-Score:  0.8571
# |---------------------------------------
#
#  analysis done
# Structural Hamming Distance (SHD): 1
# Learned graph is 1 edge(s) different from the truth.
# -------------------------
